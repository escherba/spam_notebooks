# %%
library(igraph)

# %%
df <- read.table('data/out.opsahl-southernwomen', comment.char='%', sep=' ')
df <- df[c('V1', 'V2')]

# %%
renamed <- cbind(sprintf("%s%d", "w", t(df[1])), sprintf("%s%d", "e", t(df[2])))

# %%
el <- as.matrix(renamed)

# %%
g <- graph.edgelist(el,directed=FALSE)

# %%
classes = grepl("w", V(g)$name)

# %%
V(g)$color <- ifelse(classes, "orange", "lightblue")

# %%
plot.igraph(g,layout=layout.fruchterman.reingold)
# Out:
# Plot with title “”
